# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# # Retrieving the Nearest City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 760

# %% [markdown]
# # Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | dharchula
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | sechura
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | sept-iles
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | faya
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | abnub
# Processing Record 12 of Set 1 | ngaoundere
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | komsomolskiy
# Processing Record 17 of Set 1 | ler
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | sola
# Processing Record 20 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 1 | mayskiy
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | hella
# Processing Record 31 of Set 1 | aswan
# Processing Record 32 of Set 1 | huittinen
# Processing Record 33 of Set 1 | rio verde de mato grosso
# Processing Record 34 of Set 1 | beloha
# Processing Record 35 of Set 1 | winnemucca
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | osakarovka
# Processing Record 38 of Set 1 | boyabat
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | sinnar
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | pacific grove
# Processing Record 43 of Set 1 | baykit
# Processing Record 44 of Set 1 | pindiga
# Processing Record 45 of Set 1 | nyurba
# Processing Record 46 of Set 1 | praia da vitoria
# Processing Record 47 of Set 1 | marsh harbour
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | okhotsk
# Processing Record 50 of Set 1 | huarmey
# Processing Record 1 of Set 2 | avera
# Processing Record 2 of Set 2 | katherine
# Processing Record 3 of Set 2 | nizwa
# Processing Record 4 of Set 2 | buchanan
# Processing Record 5 of Set 2 | samarai
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | mahibadhoo
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | isangel
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | urumqi
# Processing Record 14 of Set 2 | atar
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | sinazongwe
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | domoni
# Processing Record 21 of Set 2 | ekhabi
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | waingapu
# Processing Record 24 of Set 2 | tiznit
# Processing Record 25 of Set 2 | beni
# Processing Record 26 of Set 2 | baruun-urt
# Processing Record 27 of Set 2 | sipe sipe
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | kodinsk
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | havoysund
# Processing Record 33 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 2 | ugoofaaru
# Processing Record 35 of Set 2 | kununurra
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | altay
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | tomatlan
# Processing Record 42 of Set 2 | maceio
# Processing Record 43 of Set 2 | labuhan
# Processing Record 44 of Set 2 | guayaramerin
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | lata
# Processing Record 47 of Set 2 | zhanakorgan
# Processing Record 48 of Set 2 | przhevalskoye
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | olafsvik
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | mayo
# Processing Record 3 of Set 3 | kjopsvik
# Processing Record 4 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 3 | muli
# Processing Record 6 of Set 3 | sulecin
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | coolum beach
# Processing Record 11 of Set 3 | fort wellington
# Processing Record 12 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 3 | bassano
# Processing Record 16 of Set 3 | roros
# Processing Record 17 of Set 3 | airai
# Processing Record 18 of Set 3 | chiredzi
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 3 | torbay
# Processing Record 24 of Set 3 | ballina
# Processing Record 25 of Set 3 | nikolskoye
# Processing Record 26 of Set 3 | nishihara
# Processing Record 27 of Set 3 | hualmay
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | eureka
# Processing Record 34 of Set 3 | sibolga
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | trinidad
# Processing Record 37 of Set 3 | kolvereid
# Processing Record 38 of Set 3 | kahului
# Processing Record 39 of Set 3 | cienaga
# Processing Record 40 of Set 3 | nauta
# Processing Record 41 of Set 3 | gillette
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | buluang
# Processing Record 44 of Set 3 | poum
# Processing Record 45 of Set 3 | laela
# Processing Record 46 of Set 3 | tokonou
# Processing Record 47 of Set 3 | kamaishi
# Processing Record 48 of Set 3 | changping
# Processing Record 49 of Set 3 | bandarbeyla
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | gamba
# Processing Record 2 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 4 | mataura
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | neepawa
# Processing Record 6 of Set 4 | kandrian
# Processing Record 7 of Set 4 | plyussa
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | udachnyy
# Processing Record 10 of Set 4 | pokhara
# Processing Record 11 of Set 4 | boueni
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | kavieng
# Processing Record 14 of Set 4 | hryshkivtsi
# Processing Record 15 of Set 4 | nantucket
# Processing Record 16 of Set 4 | nenagh
# Processing Record 17 of Set 4 | saint-jean-port-joli
# Processing Record 18 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 4 | necochea
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 4 | charagua
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | pemangkat
# Processing Record 25 of Set 4 | umm lajj
# Processing Record 26 of Set 4 | chara
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | san rafael
# Processing Record 29 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 4 | manokwari
# Processing Record 31 of Set 4 | canon city
# Processing Record 32 of Set 4 | san juan
# Processing Record 33 of Set 4 | bengbu
# Processing Record 34 of Set 4 | butaritari
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | sinnamary
# Processing Record 38 of Set 4 | la ronge
# Processing Record 39 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 4 | nacala
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | lumsden
# Processing Record 43 of Set 4 | cottonwood
# Processing Record 44 of Set 4 | comodoro rivadavia
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | sohag
# Processing Record 47 of Set 4 | jinchang
# Processing Record 48 of Set 4 | ketchikan
# Processing Record 49 of Set 4 | hornepayne
# Processing Record 50 of Set 4 | hasaki
# Processing Record 1 of Set 5 | sakakah
# Processing Record 2 of Set 5 | hutchinson
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | derzhavinsk
# Processing Record 5 of Set 5 | kendari
# Processing Record 6 of Set 5 | mozhaysk
# Processing Record 7 of Set 5 | nurota
# Processing Record 8 of Set 5 | morada nova
# Processing Record 9 of Set 5 | tarime
# Processing Record 10 of Set 5 | adrar
# Processing Record 11 of Set 5 | banda aceh
# Processing Record 12 of Set 5 | talcahuano
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | tiksi
# Processing Record 16 of Set 5 | sioux lookout
# Processing Record 17 of Set 5 | ouadda
# Processing Record 18 of Set 5 | fukagawa
# Processing Record 19 of Set 5 | port hedland
# Processing Record 20 of Set 5 | sudislavl
# Processing Record 21 of Set 5 | calvinia
# Processing Record 22 of Set 5 | tambopata
# Processing Record 23 of Set 5 | camana
# Processing Record 24 of Set 5 | wadi maliz
# Processing Record 25 of Set 5 | cidreira
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | katsuura
# Processing Record 29 of Set 5 | cockburn town
# Processing Record 30 of Set 5 | ponta delgada
# Processing Record 31 of Set 5 | meadow lake
# Processing Record 32 of Set 5 | carman
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | izhevskoye
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | touros
# Processing Record 38 of Set 5 | ust-koksa
# Processing Record 39 of Set 5 | vardo
# Processing Record 40 of Set 5 | rabak
# Processing Record 41 of Set 5 | camara de lobos
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | araouane
# Processing Record 44 of Set 5 | mahebourg
# Processing Record 45 of Set 5 | kadyy
# Processing Record 46 of Set 5 | provaton
# City not found. Skipping...
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | alta floresta
# Processing Record 49 of Set 5 | jamestown
# Processing Record 50 of Set 5 | santa fe
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | grindavik
# Processing Record 4 of Set 6 | brownwood
# Processing Record 5 of Set 6 | west fargo
# Processing Record 6 of Set 6 | elizabeth city
# Processing Record 7 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 6 | moose factory
# Processing Record 9 of Set 6 | baturaja
# Processing Record 10 of Set 6 | nome
# Processing Record 11 of Set 6 | new norfolk
# Processing Record 12 of Set 6 | beyneu
# Processing Record 13 of Set 6 | hofn
# Processing Record 14 of Set 6 | nanning
# Processing Record 15 of Set 6 | dunedin
# Processing Record 16 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | ormara
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | machala
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | terrace
# Processing Record 22 of Set 6 | kerema
# Processing Record 23 of Set 6 | chase
# Processing Record 24 of Set 6 | khatanga
# Processing Record 25 of Set 6 | yerbogachen
# Processing Record 26 of Set 6 | chum phae
# Processing Record 27 of Set 6 | pangody
# Processing Record 28 of Set 6 | pelym
# Processing Record 29 of Set 6 | valparaiso
# Processing Record 30 of Set 6 | kefalos
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | noumea
# Processing Record 33 of Set 6 | henties bay
# Processing Record 34 of Set 6 | ulaanbaatar
# Processing Record 35 of Set 6 | agstafa
# City not found. Skipping...
# Processing Record 36 of Set 6 | cascais
# Processing Record 37 of Set 6 | danielskuil
# Processing Record 38 of Set 6 | loiza
# Processing Record 39 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | sumbe
# Processing Record 43 of Set 6 | betioky
# Processing Record 44 of Set 6 | laguna
# Processing Record 45 of Set 6 | surt
# Processing Record 46 of Set 6 | seoul
# Processing Record 47 of Set 6 | santa ana
# Processing Record 48 of Set 6 | esperance
# Processing Record 49 of Set 6 | zhangzhou
# Processing Record 50 of Set 6 | port keats
# Processing Record 1 of Set 7 | sinegorye
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | bambous virieux
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | waipawa
# Processing Record 6 of Set 7 | escanaba
# Processing Record 7 of Set 7 | kaeo
# Processing Record 8 of Set 7 | alice springs
# Processing Record 9 of Set 7 | carutapera
# Processing Record 10 of Set 7 | narsaq
# Processing Record 11 of Set 7 | springdale
# Processing Record 12 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 7 | phibun mangsahan
# Processing Record 14 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 7 | malmedy
# Processing Record 16 of Set 7 | wanaka
# Processing Record 17 of Set 7 | high prairie
# Processing Record 18 of Set 7 | port macquarie
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | carauari
# Processing Record 23 of Set 7 | chichi
# Processing Record 24 of Set 7 | san vicente
# Processing Record 25 of Set 7 | yumen
# Processing Record 26 of Set 7 | ortigueira
# Processing Record 27 of Set 7 | port elizabeth
# Processing Record 28 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 29 of Set 7 | elko
# Processing Record 30 of Set 7 | ribeira grande
# Processing Record 31 of Set 7 | pozo colorado
# Processing Record 32 of Set 7 | kashi
# Processing Record 33 of Set 7 | maldonado
# Processing Record 34 of Set 7 | kautokeino
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | turbana
# Processing Record 37 of Set 7 | sheregesh
# Processing Record 38 of Set 7 | pedasi
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 7 | conde
# Processing Record 43 of Set 7 | hami
# Processing Record 44 of Set 7 | pundaguitan
# Processing Record 45 of Set 7 | bud
# Processing Record 46 of Set 7 | qujing
# Processing Record 47 of Set 7 | portland
# Processing Record 48 of Set 7 | devarkonda
# Processing Record 49 of Set 7 | kaliua
# Processing Record 50 of Set 7 | verkhnyaya balkariya
# Processing Record 1 of Set 8 | muhos
# Processing Record 2 of Set 8 | waitati
# Processing Record 3 of Set 8 | sorrento
# Processing Record 4 of Set 8 | iqaluit
# Processing Record 5 of Set 8 | darhan
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | fortuna
# Processing Record 8 of Set 8 | minab
# Processing Record 9 of Set 8 | lyubeshiv
# City not found. Skipping...
# Processing Record 10 of Set 8 | thinadhoo
# Processing Record 11 of Set 8 | lebanon
# Processing Record 12 of Set 8 | parabel
# Processing Record 13 of Set 8 | maniitsoq
# Processing Record 14 of Set 8 | brae
# Processing Record 15 of Set 8 | mendeleyevo
# Processing Record 16 of Set 8 | meulaboh
# Processing Record 17 of Set 8 | port blair
# Processing Record 18 of Set 8 | jalu
# Processing Record 19 of Set 8 | west wendover
# Processing Record 20 of Set 8 | cayenne
# Processing Record 21 of Set 8 | blackfoot
# Processing Record 22 of Set 8 | pisco
# Processing Record 23 of Set 8 | la esperanza
# Processing Record 24 of Set 8 | okha
# Processing Record 25 of Set 8 | davila
# Processing Record 26 of Set 8 | fort collins
# Processing Record 27 of Set 8 | rawson
# Processing Record 28 of Set 8 | vikramasingapuram
# Processing Record 29 of Set 8 | quatre cocos
# Processing Record 30 of Set 8 | homer
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | bubaque
# Processing Record 33 of Set 8 | shwebo
# Processing Record 34 of Set 8 | taraz
# Processing Record 35 of Set 8 | kukushtan
# Processing Record 36 of Set 8 | hwange
# Processing Record 37 of Set 8 | farah
# Processing Record 38 of Set 8 | azul
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | luba
# Processing Record 41 of Set 8 | tabou
# Processing Record 42 of Set 8 | calabozo
# Processing Record 43 of Set 8 | fare
# Processing Record 44 of Set 8 | enshi
# Processing Record 45 of Set 8 | batagay
# Processing Record 46 of Set 8 | presidencia roque saenz pena
# Processing Record 47 of Set 8 | balakirevo
# Processing Record 48 of Set 8 | bichura
# Processing Record 49 of Set 8 | thano bula khan
# City not found. Skipping...
# Processing Record 50 of Set 8 | nanortalik
# Processing Record 1 of Set 9 | bambanglipuro
# Processing Record 2 of Set 9 | elmina
# Processing Record 3 of Set 9 | yulara
# Processing Record 4 of Set 9 | mehriz
# Processing Record 5 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 9 | shalyhyne
# Processing Record 8 of Set 9 | dhidhdhoo
# Processing Record 9 of Set 9 | erenhot
# Processing Record 10 of Set 9 | channel-port aux basques
# Processing Record 11 of Set 9 | mizdah
# Processing Record 12 of Set 9 | natal
# Processing Record 13 of Set 9 | cuitlahuac
# Processing Record 14 of Set 9 | arinos
# Processing Record 15 of Set 9 | coihaique
# Processing Record 16 of Set 9 | harper
# Processing Record 17 of Set 9 | valverde del camino
# Processing Record 18 of Set 9 | norrkoping
# Processing Record 19 of Set 9 | deep river
# Processing Record 20 of Set 9 | chapais
# Processing Record 21 of Set 9 | kambove
# Processing Record 22 of Set 9 | aller
# Processing Record 23 of Set 9 | jieshi
# Processing Record 24 of Set 9 | tuatapere
# Processing Record 25 of Set 9 | artyom
# Processing Record 26 of Set 9 | zhezkazgan
# Processing Record 27 of Set 9 | sipovo
# Processing Record 28 of Set 9 | lahij
# Processing Record 29 of Set 9 | yinchuan
# Processing Record 30 of Set 9 | chokurdakh
# Processing Record 31 of Set 9 | vostok
# Processing Record 32 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 9 | methoni
# Processing Record 34 of Set 9 | batemans bay
# Processing Record 35 of Set 9 | zhigansk
# Processing Record 36 of Set 9 | kraksaan
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | itoman
# Processing Record 39 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 9 | ancud
# Processing Record 41 of Set 9 | nakusp
# Processing Record 42 of Set 9 | zharkent
# Processing Record 43 of Set 9 | huntington
# Processing Record 44 of Set 9 | tsabong
# Processing Record 45 of Set 9 | dzhebariki-khaya
# Processing Record 46 of Set 9 | te anau
# Processing Record 47 of Set 9 | trujillo
# Processing Record 48 of Set 9 | broken hill
# Processing Record 49 of Set 9 | hoa binh
# Processing Record 50 of Set 9 | severnyy
# Processing Record 1 of Set 10 | ulaangom
# Processing Record 2 of Set 10 | east haddam
# Processing Record 3 of Set 10 | khash
# Processing Record 4 of Set 10 | lasa
# Processing Record 5 of Set 10 | alofi
# Processing Record 6 of Set 10 | los algarrobos
# Processing Record 7 of Set 10 | luderitz
# Processing Record 8 of Set 10 | arona
# Processing Record 9 of Set 10 | general roca
# Processing Record 10 of Set 10 | puerto suarez
# Processing Record 11 of Set 10 | piste
# Processing Record 12 of Set 10 | pula
# Processing Record 13 of Set 10 | tessalit
# Processing Record 14 of Set 10 | krasnoselkup
# Processing Record 15 of Set 10 | oistins
# Processing Record 16 of Set 10 | verkh-usugli
# Processing Record 17 of Set 10 | saint-francois
# Processing Record 18 of Set 10 | itarema
# Processing Record 19 of Set 10 | sorland
# Processing Record 20 of Set 10 | darab
# Processing Record 21 of Set 10 | flinders
# Processing Record 22 of Set 10 | mus
# Processing Record 23 of Set 10 | aksarka
# Processing Record 24 of Set 10 | vung tau
# Processing Record 25 of Set 10 | egvekinot
# Processing Record 26 of Set 10 | hirado
# Processing Record 27 of Set 10 | talnakh
# Processing Record 28 of Set 10 | nabisar
# Processing Record 29 of Set 10 | atbasar
# Processing Record 30 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 10 | vernon
# Processing Record 32 of Set 10 | tahe
# Processing Record 33 of Set 10 | champerico
# Processing Record 34 of Set 10 | sambava
# Processing Record 35 of Set 10 | tual
# Processing Record 36 of Set 10 | monrovia
# Processing Record 37 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 10 | roald
# Processing Record 39 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 10 | shelburne
# Processing Record 41 of Set 10 | liuzhou
# Processing Record 42 of Set 10 | bretten
# Processing Record 43 of Set 10 | griffith
# Processing Record 44 of Set 10 | japura
# Processing Record 45 of Set 10 | oktyabrskoye
# Processing Record 46 of Set 10 | lensk
# Processing Record 47 of Set 10 | pitkyaranta
# Processing Record 48 of Set 10 | krasnovishersk
# Processing Record 49 of Set 10 | vuktyl
# Processing Record 50 of Set 10 | nacozari
# Processing Record 1 of Set 11 | shakawe
# Processing Record 2 of Set 11 | bagdarin
# Processing Record 3 of Set 11 | plettenberg bay
# Processing Record 4 of Set 11 | kaputa
# Processing Record 5 of Set 11 | cabedelo
# Processing Record 6 of Set 11 | kedrovyy
# Processing Record 7 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 11 | beringovskiy
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | westport
# Processing Record 11 of Set 11 | mabopane
# Processing Record 12 of Set 11 | fort nelson
# Processing Record 13 of Set 11 | basco
# Processing Record 14 of Set 11 | tabas
# Processing Record 15 of Set 11 | general pico
# Processing Record 16 of Set 11 | lorengau
# Processing Record 17 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 18 of Set 11 | kitros
# Processing Record 19 of Set 11 | teguldet
# Processing Record 20 of Set 11 | oakland
# Processing Record 21 of Set 11 | barzas
# Processing Record 22 of Set 11 | the valley
# Processing Record 23 of Set 11 | vila franca do campo
# Processing Record 24 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 25 of Set 11 | evanston
# Processing Record 26 of Set 11 | fairbanks
# Processing Record 27 of Set 11 | islamkot
# Processing Record 28 of Set 11 | svetlaya
# Processing Record 29 of Set 11 | nioro
# Processing Record 30 of Set 11 | coffs harbour
# Processing Record 31 of Set 11 | hailar
# Processing Record 32 of Set 11 | olot
# Processing Record 33 of Set 11 | farafangana
# Processing Record 34 of Set 11 | richards bay
# Processing Record 35 of Set 11 | turayf
# Processing Record 36 of Set 11 | belozerskoye
# Processing Record 37 of Set 11 | naze
# Processing Record 38 of Set 11 | ambatondrazaka
# Processing Record 39 of Set 11 | mungwi
# Processing Record 40 of Set 11 | padang
# Processing Record 41 of Set 11 | yasenskaya
# Processing Record 42 of Set 11 | san javier
# Processing Record 43 of Set 11 | chinsali
# Processing Record 44 of Set 11 | raudeberg
# Processing Record 45 of Set 11 | penzance
# Processing Record 46 of Set 11 | esmeraldas
# Processing Record 47 of Set 11 | kampong thum
# Processing Record 48 of Set 11 | lushunkou
# City not found. Skipping...
# Processing Record 49 of Set 11 | isiro
# Processing Record 50 of Set 11 | cariamanga
# Processing Record 1 of Set 12 | navabad
# City not found. Skipping...
# Processing Record 2 of Set 12 | vilyuysk
# Processing Record 3 of Set 12 | ponta do sol
# Processing Record 4 of Set 12 | north platte
# Processing Record 5 of Set 12 | clyde river
# Processing Record 6 of Set 12 | nata
# Processing Record 7 of Set 12 | lagos
# Processing Record 8 of Set 12 | diu
# Processing Record 9 of Set 12 | yingcheng
# Processing Record 10 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 12 | dayong
# Processing Record 12 of Set 12 | catumbela
# Processing Record 13 of Set 12 | texarkana
# Processing Record 14 of Set 12 | anito
# Processing Record 15 of Set 12 | kyra
# Processing Record 16 of Set 12 | paita
# Processing Record 17 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 18 of Set 12 | vysokogornyy
# Processing Record 19 of Set 12 | gigmoto
# Processing Record 20 of Set 12 | eidfjord
# Processing Record 21 of Set 12 | ashington
# Processing Record 22 of Set 12 | changli
# Processing Record 23 of Set 12 | ola
# Processing Record 24 of Set 12 | prince rupert
# Processing Record 25 of Set 12 | kulaman
# Processing Record 26 of Set 12 | orizona
# Processing Record 27 of Set 12 | srandakan
# Processing Record 28 of Set 12 | thanh hoa
# Processing Record 29 of Set 12 | ifakara
# Processing Record 30 of Set 12 | caborca
# Processing Record 31 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 12 | moanda
# Processing Record 33 of Set 12 | ilebo
# Processing Record 34 of Set 12 | yelets
# Processing Record 35 of Set 12 | tura
# Processing Record 36 of Set 12 | kwekwe
# Processing Record 37 of Set 12 | velasco ibarra
# Processing Record 38 of Set 12 | villamontes
# Processing Record 39 of Set 12 | sao joao da barra
# Processing Record 40 of Set 12 | fiumicino
# Processing Record 41 of Set 12 | akyab
# Processing Record 42 of Set 12 | muroto
# Processing Record 43 of Set 12 | leh
# Processing Record 44 of Set 12 | vallenar
# Processing Record 45 of Set 12 | zenzeli
# Processing Record 46 of Set 12 | burnie
# Processing Record 47 of Set 12 | sorong
# Processing Record 48 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 49 of Set 12 | maputo
# Processing Record 50 of Set 12 | vikulovo
# Processing Record 1 of Set 13 | benemerito de las americas
# Processing Record 2 of Set 13 | shinyanga
# Processing Record 3 of Set 13 | kusa
# Processing Record 4 of Set 13 | mitu
# Processing Record 5 of Set 13 | vaitape
# Processing Record 6 of Set 13 | fairview
# Processing Record 7 of Set 13 | holbeach
# Processing Record 8 of Set 13 | zyryanka
# Processing Record 9 of Set 13 | ust-kuyga
# Processing Record 10 of Set 13 | kushima
# Processing Record 11 of Set 13 | shingu
# Processing Record 12 of Set 13 | bonnyville
# Processing Record 13 of Set 13 | ada
# Processing Record 14 of Set 13 | kyela
# Processing Record 15 of Set 13 | sobolevo
# Processing Record 16 of Set 13 | grand gaube
# Processing Record 17 of Set 13 | mawlaik
# Processing Record 18 of Set 13 | tefe
# Processing Record 19 of Set 13 | ostrovnoy
# Processing Record 20 of Set 13 | atocha
# Processing Record 21 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 13 | cap-aux-meules
# Processing Record 23 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 24 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 25 of Set 13 | iquique
# Processing Record 26 of Set 13 | wolbrom
# Processing Record 27 of Set 13 | savonlinna
# Processing Record 28 of Set 13 | soldatskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 13 | saint-joseph
# Processing Record 31 of Set 13 | walvis bay
# Processing Record 32 of Set 13 | port-gentil
# Processing Record 33 of Set 13 | benghazi
# Processing Record 34 of Set 13 | port moresby
# Processing Record 35 of Set 13 | sao felix do xingu
# Processing Record 36 of Set 13 | avdiyivka
# Processing Record 37 of Set 13 | bereda
# Processing Record 38 of Set 13 | nizhnyaya omka
# Processing Record 39 of Set 13 | madingou
# Processing Record 40 of Set 13 | aanekoski
# Processing Record 41 of Set 13 | huanuco
# Processing Record 42 of Set 13 | olinda
# Processing Record 43 of Set 13 | troitskoye
# Processing Record 44 of Set 13 | mehamn
# Processing Record 45 of Set 13 | mombaca
# Processing Record 46 of Set 13 | ust-maya
# Processing Record 47 of Set 13 | srednekolymsk
# Processing Record 48 of Set 13 | la sarre
# Processing Record 49 of Set 13 | werda
# Processing Record 50 of Set 13 | wundanyi
# Processing Record 1 of Set 14 | palizada
# Processing Record 2 of Set 14 | upata
# Processing Record 3 of Set 14 | sisimiut
# Processing Record 4 of Set 14 | argelia
# Processing Record 5 of Set 14 | yambio
# Processing Record 6 of Set 14 | fochabers
# Processing Record 7 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 8 of Set 14 | sorata
# Processing Record 9 of Set 14 | vulcan
# Processing Record 10 of Set 14 | piney green
# Processing Record 11 of Set 14 | oudtshoorn
# Processing Record 12 of Set 14 | soligalich
# Processing Record 13 of Set 14 | colac
# Processing Record 14 of Set 14 | panalingaan
# Processing Record 15 of Set 14 | douentza
# Processing Record 16 of Set 14 | sucua
# Processing Record 17 of Set 14 | ventspils
# Processing Record 18 of Set 14 | bonthe
# Processing Record 19 of Set 14 | dubbo
# Processing Record 20 of Set 14 | ye
# City not found. Skipping...
# Processing Record 21 of Set 14 | magaria
# Processing Record 22 of Set 14 | halden
# Processing Record 23 of Set 14 | tazovskiy
# Processing Record 24 of Set 14 | charlotte
# Processing Record 25 of Set 14 | taoudenni
# Processing Record 26 of Set 14 | monroe
# Processing Record 27 of Set 14 | black river
# Processing Record 28 of Set 14 | hobyo
# Processing Record 29 of Set 14 | coquimbo
# Processing Record 30 of Set 14 | saint-pierre
# Processing Record 31 of Set 14 | mogadishu
# Processing Record 32 of Set 14 | oranjemund
# Processing Record 33 of Set 14 | boulder
# Processing Record 34 of Set 14 | buta
# Processing Record 35 of Set 14 | marechal candido rondon
# Processing Record 36 of Set 14 | kiunga
# Processing Record 37 of Set 14 | agadir
# Processing Record 38 of Set 14 | awjilah
# Processing Record 39 of Set 14 | negotin
# Processing Record 40 of Set 14 | celestun
# Processing Record 41 of Set 14 | teya
# Processing Record 42 of Set 14 | aklavik
# Processing Record 43 of Set 14 | castrillon
# Processing Record 44 of Set 14 | la rioja
# Processing Record 45 of Set 14 | gumdag
# Processing Record 46 of Set 14 | chabahar
# Processing Record 47 of Set 14 | anadyr
# Processing Record 48 of Set 14 | dubuque
# Processing Record 49 of Set 14 | ballangen
# Processing Record 50 of Set 14 | mutuipe
# Processing Record 1 of Set 15 | ottawa
# Processing Record 2 of Set 15 | moerai
# Processing Record 3 of Set 15 | butajira
# Processing Record 4 of Set 15 | mahajanga
# Processing Record 5 of Set 15 | bourail
# Processing Record 6 of Set 15 | mount pleasant
# Processing Record 7 of Set 15 | nieves
# Processing Record 8 of Set 15 | malanje
# Processing Record 9 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 10 of Set 15 | cienaga de oro
# Processing Record 11 of Set 15 | hovd
# Processing Record 12 of Set 15 | seryshevo
# Processing Record 13 of Set 15 | krosno
# Processing Record 14 of Set 15 | sandnessjoen
# Processing Record 15 of Set 15 | malmesbury
# Processing Record 16 of Set 15 | tromso
# Processing Record 17 of Set 15 | hambantota
# Processing Record 18 of Set 15 | port shepstone
# Processing Record 19 of Set 15 | odweyne
# Processing Record 20 of Set 15 | huaihua
# Processing Record 21 of Set 15 | kuala terengganu
# Processing Record 22 of Set 15 | honiara
# Processing Record 23 of Set 15 | xining
# Processing Record 24 of Set 15 | tahoua
# Processing Record 25 of Set 15 | san miguel
# Processing Record 26 of Set 15 | tchollire
# Processing Record 27 of Set 15 | muskegon
# Processing Record 28 of Set 15 | lompoc
# Processing Record 29 of Set 15 | sebastian
# Processing Record 30 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 15 | bulgan
# Processing Record 32 of Set 15 | kabo
# Processing Record 33 of Set 15 | belaya gora
# Processing Record 34 of Set 15 | severo-yeniseyskiy
# Processing Record 35 of Set 15 | bella union
# Processing Record 36 of Set 15 | thai nguyen
# Processing Record 37 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 38 of Set 15 | taltal
# Processing Record 39 of Set 15 | opuwo
# Processing Record 40 of Set 15 | sing buri
# Processing Record 41 of Set 15 | manitouwadge
# Processing Record 42 of Set 15 | aliwal north
# Processing Record 43 of Set 15 | aksu
# Processing Record 44 of Set 15 | oban
# Processing Record 45 of Set 15 | havre-saint-pierre
# Processing Record 46 of Set 15 | gladstone
# Processing Record 47 of Set 15 | mount juliet
# Processing Record 48 of Set 15 | at-bashi
# Processing Record 49 of Set 15 | tateyama
# Processing Record 50 of Set 15 | bundaberg
# Processing Record 1 of Set 16 | pavilosta
# Processing Record 2 of Set 16 | huambo
# Processing Record 3 of Set 16 | nedjo
# Processing Record 4 of Set 16 | viedma
# Processing Record 5 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 16 | manyana
# Processing Record 7 of Set 16 | gat
# Processing Record 8 of Set 16 | mackay
# Processing Record 9 of Set 16 | vestmannaeyjar
# Processing Record 10 of Set 16 | manggar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
